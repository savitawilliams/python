# %%
list1=[10,20]
print(list1)
list1.append(30)
print(list1)
list1.append(50)
print(list1)
list1.count(30)
#list2= list1.index(30)
#list1.insert(4,40.5)
print(list1)
# Out:
# [10, 20]
# [10, 20, 30]
# [10, 20, 30, 50]
# [10, 20, 30, 50, 40.5]
